# %% [markdown]
# This folder contains my SQL practice and revision focused on
# Data Science and Data Analyst roles.
#
# # SQL for Data Science
# SQL is used in Data Science to extract, clean, transform, and analyze data from relational databases before applying statistical analysis or machine learning models.

# %% [markdown]
# ### SQL Topics for Data Science
#
# 1. Data Retrieval
# 2. Filtering & Conditions
# 3. Aggregations
# 4. Joins
# 5. Subqueries & CTEs
# 6. Window Functions
# 7. Date-Time Analysis
# 8. Data Cleaning

# %% [markdown]
# ### LeetCode SQL 50
#
# - Solved 50 SQL problems
# - Topics:
#   - Joins
#   - Group By & Having
#   - Subqueries & CTEs
#   - Window Functions
#   - Date & Time Functions
# - Difficulty: Easy to Advanced
#
# LeetCode Study Plan: (https://leetcode.com/studyplan/top-sql-50/)
#
# This practice significantly improved my query logic,
# analytical thinking, and SQL problem-solving skills
# for Data Analyst and Data Science roles..

# %% [markdown]
# sql que: (https://github.com/Shabdashri27/dec25_revision/blob/main/02_sql/que.sql.txt)

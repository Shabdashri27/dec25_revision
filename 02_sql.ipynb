# %% [markdown]
# # 01-python +sql revision
# ## hello

# %% [markdown]
# ## sql excersise

# %%
SELECT p.firstName, p.lastName, a.city, a.state
FROM Person p
LEFT JOIN Address a
ON p.personId = a.personId;
